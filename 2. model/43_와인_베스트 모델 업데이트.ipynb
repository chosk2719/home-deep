# %% [markdown]
# # 베스트 모델 만들기 - 와인 사례
# ## 이진 분류
# ## 베스트 모델 업데이트하기

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# seed 값 설정
seed = 2020
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# 데이터 입력
df_pre = pd.read_csv('../Dataset/wine.csv', header=None)
df = df_pre.sample(frac=1)
dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %%
# 모델 설정
model = Sequential([
    Dense(30, input_dim=12, activation='relu'),
    Dense(12, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')
]) 
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 30)                390
# _________________________________________________________________
# dense_5 (Dense)              (None, 12)                372
# _________________________________________________________________
# dense_6 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 875
# Trainable params: 875
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 컴파일 
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# 모델 저장 폴더 설정
import os
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

# %%
# 모델 저장 조건 설정
modelpath = MODEL_DIR + "best{epoch:03d}-{val_loss:.4f}.hdf5"

# checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1)
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)

# %%
# 모델 실행 및 저장
model.fit(X, Y, validation_split=0.2, epochs=200, batch_size=200, 
          verbose=0, callbacks=[checkpointer])
# Out:
# Epoch 00001: val_loss improved from inf to 0.59094, saving model to ./model/best001-0.5909.hdf5
#
# Epoch 00002: val_loss improved from 0.59094 to 0.31864, saving model to ./model/best002-0.3186.hdf5
#
# Epoch 00003: val_loss improved from 0.31864 to 0.27171, saving model to ./model/best003-0.2717.hdf5
#
# Epoch 00004: val_loss improved from 0.27171 to 0.25690, saving model to ./model/best004-0.2569.hdf5
#
# Epoch 00005: val_loss improved from 0.25690 to 0.24846, saving model to ./model/best005-0.2485.hdf5
#
# Epoch 00006: val_loss improved from 0.24846 to 0.23748, saving model to ./model/best006-0.2375.hdf5
#
# Epoch 00007: val_loss improved from 0.23748 to 0.22904, saving model to ./model/best007-0.2290.hdf5
#
# Epoch 00008: val_loss improved from 0.22904 to 0.21970, saving model to ./model/best008-0.2197.hdf5
#
# Epoch 00009: val_loss improved from 0.21970 to 0.21336, saving model to ./model/best009-0.2134.hdf5
#
# Epoch 00010: val_loss improved from 0.21336 to 0.21202, saving model to ./model/best010-0.2120.hdf5
#
# Epoch 00011: val_loss improved from 0.21202 to 0.20407, saving model to ./model/best011-0.2041.hdf5
#
# Epoch 00012: val_loss improved from 0.20407 to 0.19981, saving model to ./model/best012-0.1998.hdf5
#
# Epoch 00013: val_loss improved from 0.19981 to 0.19672, saving model to ./model/best013-0.1967.hdf5
#
# Epoch 00014: val_loss did not improve from 0.19672
#
# Epoch 00015: val_loss improved from 0.19672 to 0.18958, saving model to ./model/best015-0.1896.hdf5
#
# Epoch 00016: val_loss did not improve from 0.18958
#
# Epoch 00017: val_loss improved from 0.18958 to 0.18682, saving model to ./model/best017-0.1868.hdf5
#
# Epoch 00018: val_loss improved from 0.18682 to 0.18070, saving model to ./model/best018-0.1807.hdf5
#
# Epoch 00019: val_loss improved from 0.18070 to 0.17879, saving model to ./model/best019-0.1788.hdf5
#
# Epoch 00020: val_loss improved from 0.17879 to 0.17798, saving model to ./model/best020-0.1780.hdf5
#
# Epoch 00021: val_loss improved from 0.17798 to 0.17486, saving model to ./model/best021-0.1749.hdf5
#
# Epoch 00022: val_loss did not improve from 0.17486
#
# Epoch 00023: val_loss improved from 0.17486 to 0.16810, saving model to ./model/best023-0.1681.hdf5
#
# Epoch 00024: val_loss did not improve from 0.16810
#
# Epoch 00025: val_loss improved from 0.16810 to 0.16358, saving model to ./model/best025-0.1636.hdf5
#
# Epoch 00026: val_loss improved from 0.16358 to 0.16096, saving model to ./model/best026-0.1610.hdf5
#
# Epoch 00027: val_loss improved from 0.16096 to 0.15862, saving model to ./model/best027-0.1586.hdf5
#
# Epoch 00028: val_loss did not improve from 0.15862
#
# Epoch 00029: val_loss did not improve from 0.15862
#
# Epoch 00030: val_loss improved from 0.15862 to 0.15470, saving model to ./model/best030-0.1547.hdf5
#
# Epoch 00031: val_loss improved from 0.15470 to 0.15030, saving model to ./model/best031-0.1503.hdf5
#
# Epoch 00032: val_loss did not improve from 0.15030
#
# Epoch 00033: val_loss improved from 0.15030 to 0.14437, saving model to ./model/best033-0.1444.hdf5
#
# Epoch 00034: val_loss improved from 0.14437 to 0.14143, saving model to ./model/best034-0.1414.hdf5
#
# Epoch 00035: val_loss improved from 0.14143 to 0.13981, saving model to ./model/best035-0.1398.hdf5
#
# Epoch 00036: val_loss did not improve from 0.13981
#
# Epoch 00037: val_loss did not improve from 0.13981
#
# Epoch 00038: val_loss improved from 0.13981 to 0.13454, saving model to ./model/best038-0.1345.hdf5
#
# Epoch 00039: val_loss improved from 0.13454 to 0.13416, saving model to ./model/best039-0.1342.hdf5
#
# Epoch 00040: val_loss improved from 0.13416 to 0.12915, saving model to ./model/best040-0.1291.hdf5
#
# Epoch 00041: val_loss improved from 0.12915 to 0.12829, saving model to ./model/best041-0.1283.hdf5
#
# Epoch 00042: val_loss did not improve from 0.12829
#
# Epoch 00043: val_loss improved from 0.12829 to 0.12283, saving model to ./model/best043-0.1228.hdf5
#
# Epoch 00044: val_loss improved from 0.12283 to 0.12159, saving model to ./model/best044-0.1216.hdf5
#
# Epoch 00045: val_loss did not improve from 0.12159
#
# Epoch 00046: val_loss improved from 0.12159 to 0.11881, saving model to ./model/best046-0.1188.hdf5
#
# Epoch 00047: val_loss did not improve from 0.11881
#
# Epoch 00048: val_loss improved from 0.11881 to 0.11610, saving model to ./model/best048-0.1161.hdf5
#
# Epoch 00049: val_loss improved from 0.11610 to 0.11268, saving model to ./model/best049-0.1127.hdf5
#
# Epoch 00050: val_loss did not improve from 0.11268
#
# Epoch 00051: val_loss did not improve from 0.11268
#
# Epoch 00052: val_loss improved from 0.11268 to 0.10827, saving model to ./model/best052-0.1083.hdf5
#
# Epoch 00053: val_loss did not improve from 0.10827
#
# Epoch 00054: val_loss improved from 0.10827 to 0.10515, saving model to ./model/best054-0.1051.hdf5
#
# Epoch 00055: val_loss improved from 0.10515 to 0.10400, saving model to ./model/best055-0.1040.hdf5
#
# Epoch 00056: val_loss improved from 0.10400 to 0.10214, saving model to ./model/best056-0.1021.hdf5
#
# Epoch 00057: val_loss improved from 0.10214 to 0.10106, saving model to ./model/best057-0.1011.hdf5
#
# Epoch 00058: val_loss improved from 0.10106 to 0.09995, saving model to ./model/best058-0.0999.hdf5
#
# Epoch 00059: val_loss improved from 0.09995 to 0.09885, saving model to ./model/best059-0.0988.hdf5
#
# Epoch 00060: val_loss improved from 0.09885 to 0.09846, saving model to ./model/best060-0.0985.hdf5
#
# Epoch 00061: val_loss improved from 0.09846 to 0.09810, saving model to ./model/best061-0.0981.hdf5
#
# Epoch 00062: val_loss did not improve from 0.09810
#
# Epoch 00063: val_loss improved from 0.09810 to 0.09630, saving model to ./model/best063-0.0963.hdf5
#
# Epoch 00064: val_loss did not improve from 0.09630
#
# Epoch 00065: val_loss improved from 0.09630 to 0.09215, saving model to ./model/best065-0.0922.hdf5
#
# Epoch 00066: val_loss did not improve from 0.09215
#
# Epoch 00067: val_loss did not improve from 0.09215
#
# Epoch 00068: val_loss did not improve from 0.09215
#
# Epoch 00069: val_loss improved from 0.09215 to 0.08895, saving model to ./model/best069-0.0890.hdf5
#
# Epoch 00070: val_loss did not improve from 0.08895
#
# Epoch 00071: val_loss improved from 0.08895 to 0.08779, saving model to ./model/best071-0.0878.hdf5
#
# Epoch 00072: val_loss improved from 0.08779 to 0.08624, saving model to ./model/best072-0.0862.hdf5
#
# Epoch 00073: val_loss did not improve from 0.08624
#
# Epoch 00074: val_loss did not improve from 0.08624
#
# Epoch 00075: val_loss did not improve from 0.08624
#
# Epoch 00076: val_loss improved from 0.08624 to 0.08409, saving model to ./model/best076-0.0841.hdf5
#
# Epoch 00077: val_loss did not improve from 0.08409
#
# Epoch 00078: val_loss improved from 0.08409 to 0.08367, saving model to ./model/best078-0.0837.hdf5
#
# Epoch 00079: val_loss did not improve from 0.08367
#
# Epoch 00080: val_loss did not improve from 0.08367
#
# Epoch 00081: val_loss improved from 0.08367 to 0.08097, saving model to ./model/best081-0.0810.hdf5
#
# Epoch 00082: val_loss improved from 0.08097 to 0.08079, saving model to ./model/best082-0.0808.hdf5
#
# Epoch 00083: val_loss did not improve from 0.08079
#
# Epoch 00084: val_loss did not improve from 0.08079
#
# Epoch 00085: val_loss did not improve from 0.08079
#
# Epoch 00086: val_loss did not improve from 0.08079
#
# Epoch 00087: val_loss improved from 0.08079 to 0.07796, saving model to ./model/best087-0.0780.hdf5
#
# Epoch 00088: val_loss did not improve from 0.07796
#
# Epoch 00089: val_loss did not improve from 0.07796
#
# Epoch 00090: val_loss did not improve from 0.07796
#
# Epoch 00091: val_loss did not improve from 0.07796
#
# Epoch 00092: val_loss did not improve from 0.07796
#
# Epoch 00093: val_loss improved from 0.07796 to 0.07603, saving model to ./model/best093-0.0760.hdf5
#
# Epoch 00094: val_loss did not improve from 0.07603
#
# Epoch 00095: val_loss improved from 0.07603 to 0.07541, saving model to ./model/best095-0.0754.hdf5
#
# Epoch 00096: val_loss did not improve from 0.07541
#
# Epoch 00097: val_loss did not improve from 0.07541
#
# Epoch 00098: val_loss did not improve from 0.07541
#
# Epoch 00099: val_loss did not improve from 0.07541
#
# Epoch 00100: val_loss did not improve from 0.07541
#
# Epoch 00101: val_loss improved from 0.07541 to 0.07381, saving model to ./model/best101-0.0738.hdf5
#
# Epoch 00102: val_loss did not improve from 0.07381
#
# Epoch 00103: val_loss did not improve from 0.07381
#
# Epoch 00104: val_loss did not improve from 0.07381
# Epoch 00105: val_loss did not improve from 0.07381
#
# Epoch 00106: val_loss did not improve from 0.07381
#
# Epoch 00107: val_loss did not improve from 0.07381
#
# Epoch 00108: val_loss improved from 0.07381 to 0.07237, saving model to ./model/best108-0.0724.hdf5
#
# Epoch 00109: val_loss did not improve from 0.07237
#
# Epoch 00110: val_loss improved from 0.07237 to 0.07224, saving model to ./model/best110-0.0722.hdf5
#
# Epoch 00111: val_loss did not improve from 0.07224
#
# Epoch 00112: val_loss did not improve from 0.07224
#
# Epoch 00113: val_loss did not improve from 0.07224
#
# Epoch 00114: val_loss improved from 0.07224 to 0.07195, saving model to ./model/best114-0.0719.hdf5
#
# Epoch 00115: val_loss did not improve from 0.07195
#
# Epoch 00116: val_loss did not improve from 0.07195
#
# Epoch 00117: val_loss did not improve from 0.07195
#
# Epoch 00118: val_loss improved from 0.07195 to 0.07040, saving model to ./model/best118-0.0704.hdf5
#
# Epoch 00119: val_loss did not improve from 0.07040
#
# Epoch 00120: val_loss did not improve from 0.07040
#
# Epoch 00121: val_loss improved from 0.07040 to 0.06947, saving model to ./model/best121-0.0695.hdf5
#
# Epoch 00122: val_loss improved from 0.06947 to 0.06933, saving model to ./model/best122-0.0693.hdf5
#
# Epoch 00123: val_loss did not improve from 0.06933
#
# Epoch 00124: val_loss did not improve from 0.06933
#
# Epoch 00125: val_loss did not improve from 0.06933
#
# Epoch 00126: val_loss did not improve from 0.06933
#
# Epoch 00127: val_loss did not improve from 0.06933
#
# Epoch 00128: val_loss did not improve from 0.06933
#
# Epoch 00129: val_loss did not improve from 0.06933
#
# Epoch 00130: val_loss did not improve from 0.06933
#
# Epoch 00131: val_loss improved from 0.06933 to 0.06849, saving model to ./model/best131-0.0685.hdf5
#
# Epoch 00132: val_loss did not improve from 0.06849
#
# Epoch 00133: val_loss did not improve from 0.06849
#
# Epoch 00134: val_loss did not improve from 0.06849
#
# Epoch 00135: val_loss did not improve from 0.06849
#
# Epoch 00136: val_loss did not improve from 0.06849
#
# Epoch 00137: val_loss did not improve from 0.06849
#
# Epoch 00138: val_loss improved from 0.06849 to 0.06832, saving model to ./model/best138-0.0683.hdf5
#
# Epoch 00139: val_loss did not improve from 0.06832
#
# Epoch 00140: val_loss improved from 0.06832 to 0.06794, saving model to ./model/best140-0.0679.hdf5
#
# Epoch 00141: val_loss did not improve from 0.06794
#
# Epoch 00142: val_loss did not improve from 0.06794
#
# Epoch 00143: val_loss did not improve from 0.06794
#
# Epoch 00144: val_loss improved from 0.06794 to 0.06769, saving model to ./model/best144-0.0677.hdf5
#
# Epoch 00145: val_loss did not improve from 0.06769
#
# Epoch 00146: val_loss did not improve from 0.06769
#
# Epoch 00147: val_loss did not improve from 0.06769
#
# Epoch 00148: val_loss improved from 0.06769 to 0.06733, saving model to ./model/best148-0.0673.hdf5
#
# Epoch 00149: val_loss did not improve from 0.06733
#
# Epoch 00150: val_loss did not improve from 0.06733
#
# Epoch 00151: val_loss did not improve from 0.06733
#
# Epoch 00152: val_loss did not improve from 0.06733
#
# Epoch 00153: val_loss did not improve from 0.06733
#
# Epoch 00154: val_loss did not improve from 0.06733
#
# Epoch 00155: val_loss did not improve from 0.06733
#
# Epoch 00156: val_loss did not improve from 0.06733
#
# Epoch 00157: val_loss improved from 0.06733 to 0.06727, saving model to ./model/best157-0.0673.hdf5
#
# Epoch 00158: val_loss did not improve from 0.06727
#
# Epoch 00159: val_loss improved from 0.06727 to 0.06722, saving model to ./model/best159-0.0672.hdf5
#
# Epoch 00160: val_loss did not improve from 0.06722
#
# Epoch 00161: val_loss did not improve from 0.06722
#
# Epoch 00162: val_loss did not improve from 0.06722
#
# Epoch 00163: val_loss did not improve from 0.06722
#
# Epoch 00164: val_loss did not improve from 0.06722
#
# Epoch 00165: val_loss did not improve from 0.06722
#
# Epoch 00166: val_loss did not improve from 0.06722
#
# Epoch 00167: val_loss improved from 0.06722 to 0.06650, saving model to ./model/best167-0.0665.hdf5
#
# Epoch 00168: val_loss did not improve from 0.06650
#
# Epoch 00169: val_loss did not improve from 0.06650
#
# Epoch 00170: val_loss did not improve from 0.06650
#
# Epoch 00171: val_loss did not improve from 0.06650
#
# Epoch 00172: val_loss did not improve from 0.06650
#
# Epoch 00173: val_loss did not improve from 0.06650
#
# Epoch 00174: val_loss did not improve from 0.06650
#
# Epoch 00175: val_loss did not improve from 0.06650
#
# Epoch 00176: val_loss did not improve from 0.06650
#
# Epoch 00177: val_loss did not improve from 0.06650
#
# Epoch 00178: val_loss did not improve from 0.06650
#
# Epoch 00179: val_loss did not improve from 0.06650
#
# Epoch 00180: val_loss did not improve from 0.06650
#
# Epoch 00181: val_loss did not improve from 0.06650
#
# Epoch 00182: val_loss did not improve from 0.06650
#
# Epoch 00183: val_loss did not improve from 0.06650
#
# Epoch 00184: val_loss did not improve from 0.06650
#
# Epoch 00185: val_loss did not improve from 0.06650
#
# Epoch 00186: val_loss did not improve from 0.06650
#
# Epoch 00187: val_loss did not improve from 0.06650
#
# Epoch 00188: val_loss did not improve from 0.06650
#
# Epoch 00189: val_loss did not improve from 0.06650
#
# Epoch 00190: val_loss did not improve from 0.06650
#
# Epoch 00191: val_loss did not improve from 0.06650
#
# Epoch 00192: val_loss did not improve from 0.06650
#
# Epoch 00193: val_loss did not improve from 0.06650
#
# Epoch 00194: val_loss did not improve from 0.06650
#
# Epoch 00195: val_loss did not improve from 0.06650
#
# Epoch 00196: val_loss did not improve from 0.06650
#
# Epoch 00197: val_loss did not improve from 0.06650
#
# Epoch 00198: val_loss did not improve from 0.06650
#
# Epoch 00199: val_loss did not improve from 0.06650
#
# Epoch 00200: val_loss did not improve from 0.06650

# %%
del model

# %%
from tensorflow.keras.models import load_model
model = load_model('model/best192-0.0530.hdf5')

# %%
# 베스트 모델의 결과 출력 
print("\n Accuracy: %.4f" % (model.evaluate(X, Y, verbose=2)[1]))
# Out:
# 6497/6497 - 0s - loss: 0.0502 - accuracy: 0.9869
#
#  Accuracy: 0.9869
